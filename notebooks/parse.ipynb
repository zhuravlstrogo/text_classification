# %%
import requests
import json
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta, date
import re
import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('max_colwidth', None)
pd.options.display.expand_frame_repr = False

# %%
token = '9e3c614a-0bc6-4cb9-b041-1fce1c067a60'

# %%
from_date = '2023-03-25'
to_date = '2023-03-26'

headers = {
        'Accept': 'application/json'
        ,'Authorization': f'Bearer {token}'
        ,'Accept-Charset': 'UTF-8'
            }

# %%
url_comments = f'https://api.pntr.io/v1/reviews?published_at_from={from_date}&published_at_to={to_date}&with_tags=true'
comments = requests.get(url_comments, headers=headers)

# %%
json.loads(comments.text)
# Out:
# {'items': [{'author': 'Maksim Pletenev',
#    'author_avatar_url': None,
#    'company_uuid': '7f0f6459-7f93-4d12-818f-be2d06427298',
#    'id': '13597636826',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 3,
#    'provider_link': 'https://2gis.ru/firm/70000001006550382',
#    'published_at': '2023-03-25T22:32:41Z',
#    'rating': 4,
#    'reply': {'created_at': '2023-03-27T09:14:14Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T09:13:15Z',
#     'text': 'Благодарим вас за отзыв. Нам очень важно знать ваше мнение. Мы стремимся к тому, чтобы быть лучше. Проведем работу в целях улучшения качества обслуживания.'},
#    'tags': [{'id': 72, 'value': 'качество обслуживания'}],
#    'text': 'Не очень вежливый персонал. ',
#    'text_tonality': 3},
#   {'author': 'Евгений Емельянов',
#    'author_avatar_url': None,
#    'company_uuid': '824976f9-529c-4b34-a8ea-451aac30c6a2',
#    'id': '13606944840',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T22:14:40Z',
#    'rating': 1,
#    'reply': {'created_at': '2023-03-27T09:13:24Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T09:13:22Z',
#     'text': 'Благодарим вас за отзыв. Нам очень важно знать ваше мнение. Мы стремимся к тому, чтобы быть лучше. Проведем работу в целях улучшения качества обслуживания.'},
#    'tags': [{'id': 1863, 'value': 'навязывание продуктов'}],
#    'text': 'Высокомерие и навязывание кредитной карты',
#    'text_tonality': 3},
#   {'author': 'Агент Репазитория',
#    'author_avatar_url': None,
#    'company_uuid': '9d4c5ad6-2b4e-46f5-b924-c1cd6d3c7c2f',
#    'id': '13597581245',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 3,
#    'provider_link': 'https://2gis.ru/firm/2393065583731699',
#    'published_at': '2023-03-25T20:48:21Z',
#    'rating': 5,
#    'reply': {'created_at': '2023-03-27T09:14:13Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T09:13:32Z',
#     'text': 'Рады, что вам понравилось. Ждем вас снова 😃'},
#    'tags': [{'id': 1850, 'value': 'благодарность общая'}],
#    'text': 'Хз, вроде норм обслуживание, по сравнению ч другими банками ',
#    'text_tonality': 1},
#   {'author': 'Андрей Малюгин',
#    'author_avatar_url': 'https://avatars.mds.yandex.net/get-yapic/43473/Qb9oGKOoSb3vt93SWqApTKcq0g-1/islands-200',
#    'company_uuid': '73226114-7416-4b21-a78a-431048e9746d',
#    'id': '13606889874',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T20:00:53Z',
#    'rating': 1,
#    'reply': {'created_at': '2023-03-27T09:14:48Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T09:14:46Z',
#     'text': 'Поверьте, мы всегда стремимся быть лучше. Мы обязательно обсудим с руководителем офиса все детали, описанные в отзыве, и учтем ваши замечания. Примите, пожалуйста, наши извинения.'},
#    'tags': [{'id': 1229, 'value': 'очередь'}],
#    'text': 'Пытался получить карту в отделении банка получил талон так и не дождался своей очереди потому как талонов было очень много и кто был как по очереди непонятно консультантом всё равно зачем ты пришёл в банк',
#    'text_tonality': 3},
#   {'author': 'Фёдор Резкин',
#    'author_avatar_url': None,
#    'company_uuid': 'b884b03b-0f86-4b06-8175-050576179be6',
#    'id': '13606889557',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T19:48:41Z',
#    'rating': 5,
#    'reply': {'created_at': '2023-03-27T09:15:01Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T09:15:00Z',
#     'text': 'Благодарим за положительный отзыв работы. Рады, что вы остались довольны 🙂'},
#    'tags': [{'id': 1852, 'value': 'благодарность - сотрудники'}],
#    'text': 'Отдельная благодарность персоналу. Помогли очень пожилому человеку разобраться. Очень корректно профессионально, терпеливо. Благодарю.',
#    'text_tonality': 1},
#   {'author': 'Дмитрий Сапелко',
#    'author_avatar_url': 'https://avatars.mds.yandex.net/get-yapic/47747/enc-75f2cb2d701ac25c37f7aa24a8688fc0db3751ddd272a50ca3f255e1b17ad03f/islands-200',
#    'company_uuid': 'e68afd47-9e71-4aa7-a07d-9095ec1a3754',
#    'id': '13606819956',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T19:45:50Z',
#    'rating': 4,
#    'reply': {'created_at': '2023-03-27T11:32:40Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T11:32:38Z',
#     'text': 'Благодарим вас за отзыв. Обратная связь нам помогает понять наши проблемы и принять меры для улучшения сервиса и обслуживания.'},
#    'tags': [{'id': 1850, 'value': 'благодарность общая'}],
#    'text': 'А больше в Бежице и нет. Поэтому придётся подождать. Персонал вежливый и грамотный.',
#    'text_tonality': 1},
#   {'author': 'Анатолий Копачинский',
#    'author_avatar_url': 'https://avatars.mds.yandex.net/get-yapic/65952/6dAeBk7Nij8nFuMP2WjKNTTbzhk-1/islands-200',
#    'company_uuid': '7b33c708-6738-456c-8e45-ad7df85fc6ed',
#    'id': '13606944586',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T19:43:30Z',
#    'rating': 1,
#    'reply': {'created_at': '2023-03-27T11:32:58Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T11:32:56Z',
#     'text': 'Анатолий, поверьте, мы принимаем меры для того, чтобы время ожидания было минимальным. Проведем проверку в отделении и обсудим с руководителем данную проблему. Надеемся, что в дальнейшем мы не заставим вас ждать.'},
#    'tags': [{'id': 1229, 'value': 'очередь'}],
#    'text': 'Очень долгий банк',
#    'text_tonality': 3},
#   {'author': 'Галина Удалова',
#    'author_avatar_url': None,
#    'company_uuid': '3c96902e-dc76-4a51-b969-eeafa0042dfd',
#    'id': '13606576593',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T19:32:07Z',
#    'rating': 3,
#    'reply': {'created_at': '2023-03-27T11:33:12Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-27T11:33:10Z',
#     'text': 'Галина, приносим извинения за длительное ожидание. Мы проведем проверку и выясним причины длительного обслуживания. Примем меры для увеличения скорости обслуживания.'},
#    'tags': [{'id': 1229, 'value': 'очередь'}],
#    'text': 'Очень медленное обслуживание, постоянно очереди. Для меня один большой плюс- рядом 😄',
#    'text_tonality': 3},
#   {'author': "Б'АРНИ",
#    'author_avatar_url': 'https://avatars.mds.yandex.net/get-yapic/39460/kpOT0HuVHX0wQ38yF2WGRqQmMzo-1/islands-200',
#    'company_uuid': '8c0ad4b9-71d5-4fa3-a3b3-127d60bada0f',
#    'id': '13606820426',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'provider_link': 'https://yandex.ru/web-maps/org/89507785679/reviews?reviews[publicId]=c1dy9hayr0u9kzdkd1fqyx1xr4',
#    'published_at': '2023-03-25T19:14:36Z',
#    'rating': 5,
#    'reply': {'created_at': '2023-03-28T11:33:49Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-28T11:33:48Z',
#     'text': 'Благодарим за положительный отзыв работы. Рады, что вы остались довольны 🙂'},
#    'tags': [{'id': 1850, 'value': 'благодарность общая'}],
#    'text': 'Хорошее отделение в самом центре города. Обслуживающий персонал вежливый, обслужили моментально. Дебетовую карту забрал сразу,еще подключил ВТБ мобайл хороший тариф ещё под акцию попал, спасибо...',
#    'text_tonality': 1},
#   {'author': 'Светлана Панченко',
#    'author_avatar_url': 'https://avatars.mds.yandex.net/get-yapic/53031/qI2zbxEHz4AotVE7kjAN0z8G84-1/islands-200',
#    'company_uuid': 'ee1496ab-3494-4f36-89a8-9dd673cc3455',
#    'id': '13606576858',
#    'is_deleted': False,
#    'network_uuid': '54558ee6-8d4a-4070-a78f-8c3ecbc58727',
#    'provider_id': 1,
#    'published_at': '2023-03-25T19:04:50Z',
#    'rating': 5,
#    'reply': {'created_at': '2023-03-28T12:36:00Z',
#     'is_editable': False,
#     'is_removable': False,
#     'published_at': '2023-03-28T12:35:59Z',
#     'text': 'Спасибо вам, очень приятно получать обратную связь 🙏👌 Приезжайте ещё 💛'},
#    'tags': [{'id': 1850, 'value': 'благодарность общая'}],
#    'text': 'Отличное обслуживание, все качественно!',
#    'text_tonality': 1}],
#  'meta': {'limit': 10, 'offset': 0, 'total': 112}}
